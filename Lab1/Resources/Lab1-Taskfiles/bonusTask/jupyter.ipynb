# %% [markdown]
# | Field      | Information                         |
# |------------|-------------------------------------|
# | **Author** | Abdelaziz Nematallah                |
# | **Date**   | 14/11/2024                           |
# | **Desc**   | This notebook is to solve the bonus part of lab1 |
#
#
# ## Problem Description
# * The Hill cipher is vulnerable to a known plain-text attack. However, sometimes it is even enough to
#  knowonly parts of the plain-text.
# * Consider the cipher text VBIDUXANLFPYPUSFGPIDTYUHDY
# * Assume that the key-length used was four and the language of plain-text is English.
# * Our  task  is to analyze the cipher by determining the used key as well as to decrypt the complete cipher.
# * Here-fore, we may want to consider the following steps:
#   1. Analyze the cipher text by checking the letter frequencies. Since the key-length is assumed  to be four, 2-grams are of special interest. Think about why this is the case?
#   2. Sometimes, the consideration of n-grams is not enough to decrypt a ciphertext. In this case, additional knowledge about the plain text is required if we do not want to test out all possible substitutions or keys. Let’s assume we already know that “the fox” is part of the plain-text.
#   3. I.e., one of the listed cases holds true
#      * ![image.png](attachment:image.png)
#   4. To find a suitable analysis method, let’s limit our scope once more: Assume that Plain  1 corresponds to the correct mapping. I.e., when encrypting, it holds (T|H) → (V|B); (E|F) → (I|D); (O|X) → (U|X). How does this help to break the cipher?
#   5.  Now, using these assumptions, calculate the key and the plain-text by mathematical means!
#   6.   Why can this method be used to efficiently break the ciphertext, even if the exact position of the partial plaintext were unknown? Submit they key as key.txt and the plaintext as  plain.txt, along with any scripts / writeups you wrote related to this task.

# %%
# Out:
# hello
